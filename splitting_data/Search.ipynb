# %%
import numpy as np
import pandas as pd
from geopy.geocoders import GoogleV3
import json, os

def config():
    with open('config.json', 'r') as f:
        params = json.load(f)
    return params

def read_mouza(mouza_path):
    df = pd.read_csv("split_data/split_mouzas{}.csv".format(mouza_path))
    return df

# %%
def coor_search_pass1(mouzas, gmaps):
    '''
    We will later go for more passes if this fails
    '''
    
    
    
    # Storing Raw data
    raw = {}
    
    # Stats
    hit_count = 0
    
    for idx, mouza in enumerate(mouzas['name']):
        percentage = idx / len(mouzas) * 100
        try:
            result = gmaps.geocode('{}, West Bengal'.format(mouza))
            if result == None:
                raise Exception('Value Not Found')
                
            raw[mouza] = result.raw
            mouzas.set_value(idx, 'latitude', result.latitude)
            mouzas.set_value(idx, 'longitude', result.longitude)
            
            hit_count += 1
            print('{0}% \t {1} \t\t {2}'.format(percentage, mouza, result.address)) 
        except Exception as e:
            raw[mouza] = None
            mouzas.set_value(idx, 'latitude', -1)
            mouzas.set_value(idx, 'longitude', -1)
            
            print('{0}% \t {1} \t\t {2}'.format(percentage, mouza, e)) 
        
    print('Hit percent = {}%'.format(hit_count/len(mouzas)*100.0))
    return mouzas, raw

# %%
params = config()
api_key = params["api_key"]

mouza_path = int(input("Enter file no : "))
mouzas = read_mouza(mouza_path)
# Add cols to mouza
mouzas['latitude'] = pd.Series(0.0, index=mouzas.index)
mouzas['longitude'] = pd.Series(0.0, index=mouzas.index)

gmaps = GoogleV3(api_key=api_key)
# Out:
# Enter file no : 1

# %%
 test_loc , test_raw = coor_search_pass1(mouzas=mouzas[:10], gmaps=gmaps)
# Out:
# 0.0% 	 Paira 		 Paira, West Bengal 722140, India
# 10.0% 	 Simlabandh 		 Simlabandh, West Bengal 722140, India
# 20.0% 	 Bhedua 		 Bhedua, West Bengal 722203, India
# 30.0% 	 Lutia 		 Lutia, West Bengal 722145, India
# 40.0% 	 Jhapandihi 		 Jhapandihi, West Bengal, India
# 50.0% 	 Kendua 		 Kendua, West Bengal, India
# 60.0% 	 Golakpur 		 Golakpur, West Bengal, India
# 70.0% 	 Bhutardihi 		 Bhutardihi, West Bengal 722140, India
# 80.0% 	 Manora 		 Manora, West Bengal 733209, India
# 90.0% 	 Dharampur 		 Dharampur, Hooghly, West Bengal, India
# Hit percent = 100.0%

# %%
test_loc
# Out:
#      id        name  jl_number  block_id   latitude  longitude
# 0  2040       Paira         44      12.0  23.046997  86.755465
# 1  2041  Simlabandh         45      12.0  23.055767  86.747923
# 2  2042      Bhedua         46      12.0  23.200998  87.249083
# 3  2043       Lutia         47      12.0  23.024612  86.853799
# 4  2044  Jhapandihi         48      12.0  23.032173  86.757979
# 5  2045      Kendua         49      12.0  24.969577  88.244901
# 6  2046    Golakpur         50      12.0  22.932316  87.307826
# 7  2047  Bhutardihi         51      12.0  23.026325  86.763006
# 8  2048      Manora         52      12.0  26.022993  87.881977
# 9  2049   Dharampur         53      12.0  22.876870  88.384625

# %%
test_raw
# Out:
# {'Bhedua': {'address_components': [{'long_name': 'Bhedua',
#     'short_name': 'Bhedua',
#     'types': ['locality', 'political']},
#    {'long_name': 'Bankura',
#     'short_name': 'Bankura',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'West Bengal',
#     'short_name': 'WB',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'India',
#     'short_name': 'IN',
#     'types': ['country', 'political']},
#    {'long_name': '722203', 'short_name': '722203', 'types': ['postal_code']}],
#   'formatted_address': 'Bhedua, West Bengal 722203, India',
#   'geometry': {'bounds': {'northeast': {'lat': 23.2023611, 'lng': 87.250607},
#     'southwest': {'lat': 23.1993829, 'lng': 87.24807489999999}},
#    'location': {'lat': 23.2009979, 'lng': 87.2490835},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 23.2023611, 'lng': 87.2506899302915},
#     'southwest': {'lat': 23.1993829, 'lng': 87.2479919697085}}},
#   'place_id': 'ChIJ2ZNx_kSY9zkRccvoNhemyq8',
#   'types': ['locality', 'political']},
#  'Bhutardihi': {'address_components': [{'long_name': 'Bhutardihi',
#     'short_name': 'Bhutardihi',
#     'types': ['locality', 'political']},
#    {'long_name': 'Purulia',
#     'short_name': 'Purulia',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'West Bengal',
#     'short_name': 'WB',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'India',
#     'short_name': 'IN',
#     'types': ['country', 'political']},
#    {'long_name': '722140', 'short_name': '722140', 'types': ['postal_code']}],
#   'formatted_address': 'Bhutardihi, West Bengal 722140, India',
#   'geometry': {'bounds': {'northeast': {'lat': 23.0303201, 'lng': 86.7668501},
#     'southwest': {'lat': 23.0230101, 'lng': 86.7589}},
#    'location': {'lat': 23.0263255, 'lng': 86.7630057},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 23.0303201, 'lng': 86.7668501},
#     'southwest': {'lat': 23.0230101, 'lng': 86.7589}}},
#   'partial_match': True,
#   'place_id': 'ChIJVbh7vvJI9jkR8WM5pUIBkUc',
#   'types': ['locality', 'political']},
#  'Dharampur': {'address_components': [{'long_name': 'Dharampur',
#     'short_name': 'Dharampur',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': 'Hooghly',
#     'short_name': 'Hooghly',
#     'types': ['locality', 'political']},
#    {'long_name': 'Hooghly',
#     'short_name': 'Hooghly',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'West Bengal',
#     'short_name': 'WB',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'India',
#     'short_name': 'IN',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Dharampur, Hooghly, West Bengal, India',
#   'geometry': {'bounds': {'northeast': {'lat': 22.8914661, 'lng': 88.397669},
#     'southwest': {'lat': 22.869882, 'lng': 88.3689641}},
#    'location': {'lat': 22.8768695, 'lng': 88.384625},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 22.8914661, 'lng': 88.397669},
#     'southwest': {'lat': 22.869882, 'lng': 88.3689641}}},
#   'place_id': 'ChIJUfy9F0KR-DkRTy-3uwfKI6s',
#   'types': ['political', 'sublocality', 'sublocality_level_1']},
#  'Golakpur': {'address_components': [{'long_name': 'Golakpur',
#     'short_name': 'Golakpur',
#     'types': ['locality', 'political']},
#    {'long_name': 'Bankura',
#     'short_name': 'Bankura',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'West Bengal',
#     'short_name': 'WB',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'India',
#     'short_name': 'IN',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Golakpur, West Bengal, India',
#   'geometry': {'bounds': {'northeast': {'lat': 22.93853, 'lng': 87.31853},
#     'southwest': {'lat': 22.9240299, 'lng': 87.30139}},
#    'location': {'lat': 22.9323164, 'lng': 87.30782579999999},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 22.93853, 'lng': 87.31853},
#     'southwest': {'lat': 22.9240299, 'lng': 87.30139}}},
#   'place_id': 'ChIJqQSwjofs9zkRoIcKrLmQIPc',
#   'types': ['locality', 'political']},
#  'Jhapandihi': {'address_components': [{'long_name': 'Jhapandihi',
#     'short_name': 'Jhapandihi',
#     'types': ['locality', 'political']},
#    {'long_name': 'Purulia',
#     'short_name': 'Purulia',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'West Bengal',
#     'short_name': 'WB',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'India',
#     'short_name': 'IN',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Jhapandihi, West Bengal, India',
#   'geometry': {'bounds': {'northeast': {'lat': 23.0390401, 'lng': 86.76673},
#     'southwest': {'lat': 23.02583, 'lng': 86.74846}},
#    'location': {'lat': 23.0321731, 'lng': 86.75797870000001},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 23.0390401, 'lng': 86.76673},
#     'southwest': {'lat': 23.02583, 'lng': 86.74846}}},
#   'partial_match': True,
#   'place_id': 'ChIJsflq6ZNI9jkREov-MH-cJIQ',
#   'types': ['locality', 'political']},
#  'Kendua': {'address_components': [{'long_name': 'Kendua',
#     'short_name': 'Kendua',
#     'types': ['locality', 'political']},
#    {'long_name': 'Malda',
#     'short_name': 'Malda',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'West Bengal',
#     'short_name': 'WB',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'India',
#     'short_name': 'IN',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Kendua, West Bengal, India',
#   'geometry': {'bounds': {'northeast': {'lat': 24.97678, 'lng': 88.2522},
#     'southwest': {'lat': 24.96433, 'lng': 88.23863999999999}},
#    'location': {'lat': 24.9695767, 'lng': 88.24490139999999},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 24.97678, 'lng': 88.2522},
#     'southwest': {'lat': 24.96433, 'lng': 88.23863999999999}}},
#   'place_id': 'ChIJrX_17KUG-zkR7ajaaPenei8',
#   'types': ['locality', 'political']},
#  'Lutia': {'address_components': [{'long_name': 'Lutia',
#     'short_name': 'Lutia',
#     'types': ['locality', 'political']},
#    {'long_name': 'Purulia',
#     'short_name': 'Purulia',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'West Bengal',
#     'short_name': 'WB',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'India',
#     'short_name': 'IN',
#     'types': ['country', 'political']},
#    {'long_name': '722145', 'short_name': '722145', 'types': ['postal_code']}],
#   'formatted_address': 'Lutia, West Bengal 722145, India',
#   'geometry': {'bounds': {'northeast': {'lat': 23.0256587, 'lng': 86.8553202},
#     'southwest': {'lat': 23.0235439, 'lng': 86.85232599999999}},
#    'location': {'lat': 23.0246121, 'lng': 86.853799},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 23.0259502802915, 'lng': 86.8553202},
#     'southwest': {'lat': 23.0232523197085, 'lng': 86.85232599999999}}},
#   'place_id': 'ChIJo74WOyFG9jkRIM5TN-pkSsw',
#   'types': ['locality', 'political']},
#  'Manora': {'address_components': [{'long_name': 'Manora',
#     'short_name': 'Manora',
#     'types': ['locality', 'political']},
#    {'long_name': 'Uttar Dinajpur',
#     'short_name': 'Uttar Dinajpur',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'West Bengal',
#     'short_name': 'WB',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'India',
#     'short_name': 'IN',
#     'types': ['country', 'political']},
#    {'long_name': '733209', 'short_name': '733209', 'types': ['postal_code']}],
#   'formatted_address': 'Manora, West Bengal 733209, India',
#   'geometry': {'bounds': {'northeast': {'lat': 26.0265501,
#      'lng': 87.89497999999999},
#     'southwest': {'lat': 26.0141701, 'lng': 87.87412}},
#    'location': {'lat': 26.0229926, 'lng': 87.88197699999999},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 26.0265501, 'lng': 87.89497999999999},
#     'southwest': {'lat': 26.0141701, 'lng': 87.87412}}},
#   'place_id': 'ChIJ12vIVdc_5TkRSlyBOoM254g',
#   'types': ['locality', 'political']},
#  'Paira': {'address_components': [{'long_name': 'Paira',
#     'short_name': 'Paira',
#     'types': ['locality', 'political']},
#    {'long_name': 'Purulia',
#     'short_name': 'Purulia',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'West Bengal',
#     'short_name': 'WB',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'India',
#     'short_name': 'IN',
#     'types': ['country', 'political']},
#    {'long_name': '722140', 'short_name': '722140', 'types': ['postal_code']}],
#   'formatted_address': 'Paira, West Bengal 722140, India',
#   'geometry': {'bounds': {'northeast': {'lat': 23.05621, 'lng': 86.76249},
#     'southwest': {'lat': 23.04006, 'lng': 86.74798}},
#    'location': {'lat': 23.0469966, 'lng': 86.755465},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 23.05621, 'lng': 86.76249},
#     'southwest': {'lat': 23.04006, 'lng': 86.74798}}},
#   'place_id': 'ChIJLzwitLtI9jkRwIqb_joVnX0',
#   'types': ['locality', 'political']},
#  'Simlabandh': {'address_components': [{'long_name': 'Simlabandh',
#     'short_name': 'Simlabandh',
#     'types': ['locality', 'political']},
#    {'long_name': 'Bankura',
#     'short_name': 'Bankura',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'West Bengal',
#     'short_name': 'WB',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'India',
#     'short_name': 'IN',
#     'types': ['country', 'political']},
#    {'long_name': '722140', 'short_name': '722140', 'types': ['postal_code']}],
#   'formatted_address': 'Simlabandh, West Bengal 722140, India',
#   'geometry': {'bounds': {'northeast': {'lat': 23.06204,
#      'lng': 86.75578999999999},
#     'southwest': {'lat': 23.0501799, 'lng': 86.73701}},
#    'location': {'lat': 23.0557671, 'lng': 86.7479232},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 23.06204, 'lng': 86.75578999999999},
#     'southwest': {'lat': 23.0501799, 'lng': 86.73701}}},
#   'place_id': 'ChIJtS0ITKlI9jkR6m3SPyJc720',
#   'types': ['locality', 'political']}}

# %%
def save_results(df, raw, path='results/'):
    final_directory = os.path.join(os.getcwd(), path)
    if not os.path.exists(final_directory):
        os.mkdir(final_directory)

    df.to_csv('{}mouzas_coor{}.csv'.format(final_directory, mouza_path), index=False)
    with open('{}mouzas_raw{}.json'.format(final_directory, mouza_path), 'w') as f:
        json.dump(raw, f, indent=4)

# %%
save_results(test_loc, test_raw)

# %%
os.path.join(os.getcwd(), 'results')
# Out:
# '/home/guardian/MEGA/tessellateX/data_sampling/splitting data/results'
